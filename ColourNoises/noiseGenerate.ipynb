# %%
import numpy as np
import matplotlib.pyplot as plt
from ColoursNoises import *
import seaborn as sns
import pandas as pd
from scipy.stats import chi2_contingency

# %% [markdown]
# # Тесты класса-генератора

# %%
ts = NOISE.pink_noise(500, 10)

# %%
NOISE.plot_spectrum(ts)

# %%
NOISE.plot_noise(ts)

# %%
ts1 = NOISE.white_noise(500, 50)
ts2 = NOISE.white_noise(500, 50)

# ts = NOISE.blue_noise(500, 10)
# ts = NOISE.violet_noise(500, 10)
# ts = NOISE.brownian_noise(500, 10)
# ts = NOISE.pink_noise(500, 10)

# %%
data = {'Value': ts1}
data = pd.DataFrame(data, columns=['Value'])
data
# Out:
#           Value
# 0     -7.953677
# 1     30.374699
# 2     18.875883
# 3    113.025762
# 4    -40.064128
# ..          ...
# 495  -29.493060
# 496    3.888042
# 497  -58.941443
# 498  -25.017863
# 499   53.387973
#
# [500 rows x 1 columns]

# %%
sns.displot(data, x="Value", kind="kde", bw_adjust=0.2)
